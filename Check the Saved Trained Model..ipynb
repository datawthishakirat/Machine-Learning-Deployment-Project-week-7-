# %% [markdown]
# # Check saved model

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'app.py.ipynb', 'Check the Saved Trained Model..ipynb', 'housing_model.pkl', 'streamlit_app.ipynb', 'streamlit_app.py.py', 'test_api.py.ipynb']

# %% [markdown]
# test the model

# %%
import joblib

model = joblib.load('housing_model.pkl')

print(model)
# Out:
# RandomForestRegressor(min_samples_split=5, n_estimators=200, random_state=42)
