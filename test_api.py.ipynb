# %% [markdown]
# # Cheaking if prediction works

# %%
import requests

url = "http://127.0.0.1:5000/predict"

data = {
    'area': 7420,
    'bedrooms': 4,
    'bathrooms': 2,
    'stories': 3,
    'parking': 2,
    'total_rooms': 6,
    'area_per_bedroom': 1855,
    'has_parking': 1,
    'luxury_home': 1,
    'mainroad_yes': 1,
    'guestroom_yes': 0,
    'basement_yes': 0,
    'hotwaterheating_yes': 0,
    'airconditioning_yes': 1,
    'prefarea_yes': 1,
    'furnishingstatus_semi-furnished': 0,
    'furnishingstatus_unfurnished': 0
}

response = requests.post(url, json=data)

print(response.text)
# Out:
# {"Predicted Price":8891042.056313131}
